# %% [markdown]
# # Mac-Morpho

# %%
# Documento de exemplo
texto = 'Águas passadas não movem moinhos'

# %%
import nltk
nltk.download('mac_morpho')

palavras_tags = nltk.corpus.mac_morpho.tagged_words()
from collections import defaultdict

palavras_tags = [(palavra.lower(), pos) for (palavra, pos) in palavras_tags]
palavras_tags = defaultdict(lambda:'??', palavras_tags)

def tag(sent):
    palavras = sent.lower().split()
    return [(p, palavras_tags[p]) for p in palavras]
# Out:
# [nltk_data] Downloading package mac_morpho to
# [nltk_data]     /home/brunorosilva/nltk_data...
# [nltk_data]   Package mac_morpho is already up-to-date!

# %%
g_tagged= tag(guarani)

# %%
from tqdm.notebook import tqdm
# Out:
# ['O Guarani, de José de Alencar\nFonte:\nALENCAR, José de', ' O guarani', ' 20a ed', ', São Paulo: Ática, 1996 (Bom Livro)', '\nTexto proveniente de:\nA Biblioteca Virtual do Estudante Brasileiro <http://www', 'bibvirt', 'futuro', 'usp', 'br>\nA Escola do Futuro da Universidade de São Paulo\nPermitido o uso apenas para fins educacionais', '\nEste material pode ser redistribuído livremente, desde que não seja alterado, e que as informações acima sejam\nmantidas']

# %% [markdown]
# # POS-tagging com spaCy

# %%
# Instalação/atualização do spaCy e dos modelos de língua
# !pip3 install -U spacy

# !python3 -m spacy download pt_core_news_sm  # Notar o "sm": Small Model
# Out:
# Requirement already up-to-date: spacy in /home/brunorosilva/.local/lib/python3.8/site-packages (3.0.5)
# ...
# 2021-03-10 18:25:37.568059: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ros/noetic/lib
# 2021-03-10 18:25:37.568100: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
# Importação do módulo e do modelo de língua
import spacy
nlp = spacy.load('pt_core_news_sm')

# %%
doc = nlp(texto)

# %%
guarani_frases = guarani.split('.')
# Out:
# 'O Gu'

# %%
for token in doc:
    print(token.text, token.pos_)
# Out:
# Águas NOUN
# passadas VERB
# não ADV
# movem VERB
# moinhos NOUN

# %% [markdown]
# # Análise de Dependências

# %%
for token in doc:
    print(token.text, token.dep_)
# Out:
# Águas nsubj
# passadas ROOT
# não advmod
# movem xcomp
# moinhos obj

# %%
# Exibição gráfica das dependências
from spacy import displacy

displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="535a63b2f81c451cb52fccf85dc52be0-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Águas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">passadas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
# Gravação da imagem gerada em arquivo
from pathlib import Path

svg = displacy.render(doc, style="dep", jupyter=False)
output_path = Path("sentence.svg")
output_path.open("w", encoding="utf-8").write(svg)
# Out:
# 3864

# %% [markdown]
# ---

# %%
# Importação do módulo e do modelo de língua
import spacy
nlp = spacy.load('pt_core_news_sm')

# %%
doc = nlp(guarani)

# %%
doc
# Out:
# O Guarani, de José de Alencar
# Fonte:
# ALENCAR, José de. O guarani. 20a ed., São Paulo: Ática, 1996 (Bom Livro).
# Texto proveniente de:
# A Biblioteca Virtual do Estudante Brasileiro <http://www.bibvirt.futuro.usp.br>
# A Escola do Futuro da Universidade de São Paulo
# Permitido o uso apenas para fins educacionais.
# Este material pode ser redistribuído livremente, desde que não seja alterado, e que as informações acima sejam
# mantidas. Para maiores informações, escreva para <bibvirt@futuro.usp.br>.
# Estamos em busca de patrocinadores e voluntários para nos ajudar a manter este projeto. Se você quer ajudar de
# alguma forma, mande um e-mail para <bibvirt@futuro.usp.br> e saiba como isso é possível.
#                                                  O Guarani
#                                                   José de Alencar
#                                                    PRÓLOGO
# Minha prima. — Gostou da minha história, e pede-me um romance; acha que posso fazer
# ...

# %%
for token in doc:
    print(token.text, token.pos_)
# Out:
# O DET
# Guarani PROPN
# , PUNCT
# de ADP
# José PROPN
# de ADP
# Alencar PROPN
#
#  SPACE
# Fonte PROPN
# : PUNCT
#
#  SPACE
# ALENCAR PROPN
# , PUNCT
# José PROPN
# de ADP
# . PUNCT
# O DET
# guarani NOUN
# . PUNCT
# 20a ADJ
# ed. NOUN
# , PUNCT
# São PROPN
# Paulo PROPN
# : PUNCT
# Ática PROPN
# , PUNCT
# 1996 NUM
# ( PUNCT
# Bom PROPN
# Livro PROPN
# ) PUNCT
# . PUNCT
#
#  SPACE
# Texto NOUN
# proveniente ADJ
# de ADP
# : PUNCT
#
#  SPACE
# A DET
# Biblioteca PROPN
# Virtual PROPN
# do ADP
# Estudante PROPN
# Brasileiro PROPN
# < PROPN
# http://www.bibvirt.futuro.usp.br NOUN
# > NUM
#
#  SPACE
# A DET
# Escola PROPN
# do ADP
# Futuro PROPN
# da ADP
# Universidade PROPN
# de ADP
# São PROPN
# Paulo PROPN
#
#  SPACE
# Permitido VERB
# o DET
# uso NOUN
# apenas ADV
# para ADP
# fins NOUN
# educacionais ADJ
# . PUNCT
#
#  SPACE
# Este DET
# material NOUN
# pode VERB
# ser AUX
# redistribuído VERB
# livremente ADV
# , PUNCT
# desde ADP
# que SCONJ
# não ADV
# seja AUX
# alterado VERB
# ...

# %% [markdown]
# # Análise de Dependências

# %%
doc = nlp(guarani)
guarani_dep_dict = {}
for frase in nlp(guarani.split('.')[0]):
    displacy.render(frase, style="dep", jupyter=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-0828281b54c8> in <module>
# ----> 1 doc = nlp(guarani)
#       2 guarani_dep_dict = {}
#       3 for frase in nlp(guarani.split('.')[0]):
#       4     displacy.render(frase, style="dep", jupyter=True)
#
# ~/.local/lib/python3.8/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     988                 error_handler = proc.get_error_handler()
#     989             try:
# --> 990                 doc = proc(doc, **component_cfg.get(name, {}))
#     991             except KeyError as e:
#     992                 # This typically happens if a component is not initialized
#
# KeyboardInterrupt:

# %%
import pandas as pd
doc = nlp(abolic)

# %%
import numpy as np

# %%
doc.vector
# Out:
# array([-0.04866292,  0.36363277,  0.72227746, -0.13653626,  0.35072395,
#         0.9211518 ,  0.43608865,  0.57878464,  0.7000071 , -0.373154  ,
#        -0.45434955, -0.12398855, -0.5174805 , -0.13214336, -0.649863  ,
#        -0.13105635,  0.07428289, -0.21400018,  0.7518919 ,  0.29558748,
#        -0.97508436,  0.03769711, -0.5803189 ,  0.32459876, -0.62458587,
#        -1.0326047 ,  0.22329292, -1.1914387 ,  0.2899589 , -0.22987668,
#        -0.30333728, -0.4639441 , -0.38750836, -0.7458546 ,  1.1293201 ,
#        -0.5133441 ,  0.48860273,  0.31709853,  0.1324611 ,  1.0599222 ,
#        -1.2540827 , -0.44972366,  0.13139202, -0.4016698 , -0.16637456,
#         0.14859256,  0.77374727, -0.05313634, -0.42913952,  0.19148533,
#         1.7593085 ,  0.05697046, -0.722091  , -0.2107848 ,  0.5783648 ,
#        -0.47192016, -0.04885002,  0.03709979,  0.02124427,  0.56904763,
#        -0.13604863, -0.12378675,  0.18286033, -0.16613056,  1.0334618 ,
# ...

# %%
doc1=nlp(guarani)
doc2=nlp(x)

# %%
k = np.array([token.vector for token in doc1]).mean(axis=0)
k2 = np.array([token.vector for token in doc2]).mean(axis=0)

# %%
doc1.similarity(doc2)
# Out:
# <ipython-input-88-d3bf01ccd94a>:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   doc1.similarity(doc2)
# 0.9626624771901486

# %%
doc3 = nlp(abolic)
doc4 = nlp(dom_casm)

# %%
dados = pd.DataFrame()
sent_tokenizer = nltk.data.load('tokenizers/punkt/portuguese.pickle')

sent = sent_tokenizer.tokenize(t)
temp_1 = pd.DataFrame({
    "Sentenças":[len(sent)],
    "Texto":["Guarani"]
})
sent = sent_tokenizer.tokenize(t)
temp_1 = pd.DataFrame({
    "Sentenças":[len(sent)],
    "Texto":["Suspeito"]
})
sent = sent_tokenizer.tokenize(t)
temp_1 = pd.DataFrame({
    "Sentenças":[len(sent)],
    "Texto":[t]
})
sent = sent_tokenizer.tokenize(t)
temp_1 = pd.DataFrame({
    "Sentenças":[len(sent)],
    "Texto":[t]
})

# %%
def sents(string):
    doc = nlp(string)
    return doc.sents

# %%
token_sentenca = {}
token_sentenca["Guarani"] = sents(guarani)
token_sentenca["Dom"] = sents(dom_casm)
token_sentenca["Abol"] = sents(abolic)
token_sentenca["X"] = sents(x)

# %%
media_advmod = {}
for livro in token_sentenca:
    num = 0
    denominador = len(token_sentenca[livro])
    for sentenca in token_sentenca[livro]:
        doc = nlp(str(sentenca))
        advmod = [1 for token in doc if token.dep_ == 'advmod']
        num += len(advmod)
    media_advmod[livro] = num / denominador
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-e9d58ea441da> in <module>
#       2 for livro in token_sentenca:
#       3     num = 0
# ----> 4     denominador = len(token_sentenca[livro])
#       5     for sentenca in token_sentenca[livro]:
#       6         doc = nlp(str(sentenca))
#
# TypeError: object of type 'generator' has no len()

# %%
media_advmod

# %%
media_punct = {}
for livro in token_sentenca:
    num = 0
    denominador = len(token_sentenca[livro])
    for sentenca in token_sentenca[livro]:
        doc = nlp(str(sentenca))
        punct = [1 for token in doc if token.dep_ == 'punct']
        num += len(punct)
    media_punct[livro] = num / denominador

# %%
media_punct

# %%
media_advers = {}
for livro in token_sentenca:
    num = 0
    denominador = len(token_sentenca[livro])
    for sentenca in token_sentenca[livro]:
        doc = nlp(str(sentenca))
        advers = [1 for token in doc if token.dep_ == 'punct']
        num += len(punct)
    media_advers[livro] = num / denominador

# %%
media_advers

# %%
doc[1]
# Out:
# Abolicionismo

# %%
doc1.vector
# Out:
# array([-0.1764933 ,  0.21209545,  0.44230655, -0.3237169 ,  0.29366046,
#         0.82572   ,  0.59083766,  0.8116519 ,  0.97548646, -0.08624925,
#        -0.29676646,  0.23606567, -0.5426365 , -0.26446968, -0.4343611 ,
#         0.06243744,  0.33927196, -0.22253233,  0.6179903 ,  0.19465484,
#        -0.8808567 ,  0.3547354 , -0.7526371 ,  0.26742488, -0.661564  ,
#        -0.91351074,  0.3743529 , -1.4821035 ,  0.5157774 , -0.26893   ,
#         0.29348898, -0.79686207, -0.42400062, -1.0421906 ,  1.0458924 ,
#        -0.33107296,  0.5079236 ,  0.5684596 ,  0.18627588,  1.4139256 ,
#        -1.1726894 , -0.66101944,  0.13272879, -0.36096802, -0.07361831,
#         0.15829746,  0.74408966, -0.2684358 , -0.31841773,  0.1635828 ,
#         1.4420278 ,  0.10827374, -0.8788441 , -0.30971098,  0.55631876,
#        -0.28311682,  0.07067484,  0.05816448,  0.18988857,  0.9214112 ,
#        -0.08845992,  0.04188407, -0.01465302, -0.14958358,  0.961686  ,
# ...

# %%
print("Similaridade entre Guarani e Texto Suspeito:", doc1. similarity(doc2))
print("Similaridade entre Abolição e Texto Suspeito:", doc3.similarity(doc2))
print("Similaridade entre Dom Casmurro e Texto Suspeito:", doc4.similarity(doc2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-fff146b500b4> in <module>
# ----> 1 print("Similaridade entre Guarani e Texto Suspeito:", doc1.similarity(doc2, 'ADJ'))
#       2 print("Similaridade entre Abolição e Texto Suspeito:", doc3.similarity(doc2))
#       3 print("Similaridade entre Dom Casmurro e Texto Suspeito:", doc4.similarity(doc2))
#
# TypeError: similarity() takes exactly one argument (2 given)

# %%
k2
# Out:
# array([ 0.16277449,  0.12107132,  0.43122724, -0.34390065,  0.66842765,
#         1.1983728 ,  0.6793818 ,  0.62964106,  0.83354187, -0.19952382,
#        -0.13815689,  0.20277502, -0.67389214, -0.15829827, -0.59237975,
#         0.03626326,  0.06642853, -0.26887375,  0.38889235,  0.08305319,
#        -0.9275136 ,  0.22058906, -0.640631  ,  0.55375755, -0.6711606 ,
#        -0.8828826 ,  0.5251082 , -1.4351205 ,  0.3506957 ,  0.15853995,
#        -0.04199322, -0.6635995 , -0.49036536, -1.1332805 ,  1.1574774 ,
#        -0.3244883 ,  0.3849552 ,  0.81810313, -0.09051242,  1.2796615 ,
#        -1.2608702 , -0.4657754 ,  0.19620971, -0.30703235,  0.04799381,
#         0.1731692 ,  0.8213093 ,  0.01301766, -0.16091232, -0.12520291,
#         1.7070537 ,  0.22508113, -0.777291  , -0.3877174 ,  0.49052683,
#        -0.5692099 ,  0.08443721,  0.20893764,  0.07276769,  0.87199956,
#         0.02103276,  0.24451305, -0.12869892, -0.30390933,  0.8160713 ,
# ...

# %%
k
# Out:
# array([-0.1764933 ,  0.21209545,  0.44230655, -0.3237169 ,  0.29366046,
#         0.82572   ,  0.59083766,  0.8116519 ,  0.97548646, -0.08624925,
#        -0.29676646,  0.23606567, -0.5426365 , -0.26446968, -0.4343611 ,
#         0.06243744,  0.33927196, -0.22253233,  0.6179903 ,  0.19465484,
#        -0.8808567 ,  0.3547354 , -0.7526371 ,  0.26742488, -0.661564  ,
#        -0.91351074,  0.3743529 , -1.4821035 ,  0.5157774 , -0.26893   ,
#         0.29348898, -0.79686207, -0.42400062, -1.0421906 ,  1.0458924 ,
#        -0.33107296,  0.5079236 ,  0.5684596 ,  0.18627588,  1.4139256 ,
#        -1.1726894 , -0.66101944,  0.13272879, -0.36096802, -0.07361831,
#         0.15829746,  0.74408966, -0.2684358 , -0.31841773,  0.1635828 ,
#         1.4420278 ,  0.10827374, -0.8788441 , -0.30971098,  0.55631876,
#        -0.28311682,  0.07067484,  0.05816448,  0.18988857,  0.9214112 ,
#        -0.08845992,  0.04188407, -0.01465302, -0.14958358,  0.961686  ,
# ...

# %%
df = pd.DataFrame()
for token in doc[1000:41000]:
    temp = pd.DataFrame({
        "Palavra":token.text,
        "Classe":token.pos_,
        "Texto":"Abolic",
    }, index=[0])
    df = df.append(temp, ignore_index=False)

# %%
doc.av

# %%
df.groupby("Classe").count()
# Out:
#         Palavra  Texto
# Classe
# ADJ        2240   2240
# ADP        5704   5704
# ADV        1937   1937
# AUX        1017   1017
# CCONJ      1221   1221
# DET        4300   4300
# INTJ          2      2
# NOUN       7832   7832
# NUM         752    752
# PRON       2058   2058
# PROPN       993    993
# PUNCT      4486   4486
# SCONJ      1120   1120
# SPACE      2409   2409
# SYM          11     11
# VERB       3913   3913
# X             5      5

# %%
df.groupby("Classe").count()
# Out:
#         Palavra  Texto
# Classe
# ADJ        1883   1883
# ADP        4830   4830
# ADV        1490   1490
# AUX         597    597
# CCONJ      1111   1111
# DET        4313   4313
# INTJ         25     25
# NOUN       8345   8345
# NUM         253    253
# PART          1      1
# PRON       1619   1619
# PROPN      1517   1517
# PUNCT      4906   4906
# SCONJ      1011   1011
# SPACE      3360   3360
# SYM           2      2
# VERB       4709   4709
# X            28     28

# %%
df.groupby("Classe").count()
# Out:
#         Palavra  Texto
# Classe
# ADJ        1896   1896
# ADP        4629   4629
# ADV        1689   1689
# AUX         797    797
# CCONJ      1296   1296
# DET        4390   4390
# INTJ         27     27
# NOUN       7560   7560
# NUM         477    477
# PRON       2276   2276
# PROPN      1225   1225
# PUNCT      4867   4867
# SCONJ      1013   1013
# SPACE      2724   2724
# VERB       5132   5132
# X             2      2

# %%
# Exibição gráfica das dependências
from spacy import displacy

displacy.render(doc, style="dep", jupyter=True)

# %%
# Gravação da imagem gerada em arquivo
from pathlib import Path

svg = displacy.render(doc, style="dep", jupyter=False)
output_path = Path("sentence.svg")
output_path.open("w", encoding="utf-8").write(svg)
# Out:
# 3864

# %% [markdown]
# # Exercício
#
# 1. Sabemos que o corpus Mac-Morpho é constituído de notícias de jornal. Através de uma análise de dependências, avalie qual a função gramatical mais comum destas palavras:
#
# - Dinheiro
# - Investidores
# - (qualquer outra de seu interesse)
#
# Discuta como aproveitar esses resultados na extração de informações dos documentos.

# %% [markdown]
# # Tarefa em grupo: um pouco de Linguística Forense
#
# Seu grupo de especialistas em PLN foi chamado para periciar um texto de autor incógnito. Há três elementos suspeitos de ser o autor da obra. Todos negam veementemente a autoria. São eles:
#
# * Machado de Assis, autor de "Dom Casmurro"
# * José de Alencar, autor de "O Guarani"
# * Joaquim Nabuco, autor de "O Abolicionismo"
#
# Você tem à disposição esses livros para comparar com o livro apócrifo.
#
# Em suas análises, use alguns dos recursos comuns da Linguística Forense:
#
# * Análise das divisões de período (pontuação);
# * Comparação das colocações adverbiais, em especial os modais (etiqueta de dependência: "advmod") e as adversativas ("mas", "entretanto" etc.).
#
# Ao final, responda: quem é o autor do livro apócrifo?

# %%
def read_file(filename):
    f = open(filename, 'r')
    text = f.read()
    f.close()
    return text

guarani  = read_file('Guarani.txt')
dom_casm = read_file('DomCasmurro.txt')
abolic   = read_file('Abolicionismo.txt')
x        = read_file('TextoSuspeito.txt')

# %%
import spacy
from collections import Counter
import nltk
nltk.download('punkt')
def compute_statistics(text):
    """
    Essa função cria um dataframe com indicadores
    para a análise linguística a partir de um texto.
    """
    ### Helper functions
    
    def limpar(lista):
        return [i.lower() for i in lista if i.isalpha()]
    # Para criar uma lista de hápax legômena
    def hapax(lista):
        return [i for i in lista if lista.count(i) == 1]

    # Para eliminá-los da lista de tokens
    def sem_hapax(lista):
        return [i for i in lista if lista.count(i) > 1]
    
    # Tokenização de palavras e pontuação
    def tokenizar(string):
        doc = nlp(string)
        return [t.text for t in doc]  #  Lista de atributos .text de cada token

    def sents(string):
        doc = nlp(string)
        return doc.sents 

    def lema(string):
        doc = nlp(string)
        return [token.lemma_ for token in doc]

    ### análise de divisões de período

    nltk.download('rslp')
    raiz = nltk.stem.RSLPStemmer().stem
    nlp = spacy.load('pt_core_news_sm')
    nltk.download('stopwords')
    stops_nltk = nltk.corpus.stopwords.words('portuguese')
    stops_spacy = nlp.Defaults.stop_words
    stops = set(stops_nltk) | stops_spacy

    
    print('Caracteres: ', len(text))
    print('Caracteres sem espaços: ', len(text) - text.count(' '))
    tokens = limpar(tokenizar(text))
    print('Palavras: ', len(tokens))
    print('Riqueza lexical: ', len(set(tokens)) / len(tokens))

    #c = Counter(tokens)
    #for e, i in enumerate(c.most_common(20)):
    #    print(e, i)

    lemas = lema(' '.join(tokens))
    vocab = set(lemas)
    print('Vocabulário: ', len(vocab), ' palavras.')
    print('Riqueza vocabular: ', len(vocab) / len(lemas))
    
    raizes = [raiz(t) for t in tokens]
    print('Cardinalidade do conjunto de raízes: ', len(set(raizes)))
    
    
    hap = hapax(tokens)
    print('Os hápax legômena ocupam ', len(hap)/len(set(tokens)), ' do conjunto total de tokens.')
    
    tokens_plenos = [t for t in tokens if t not in stops]
    tokens_plenos_2 = sem_hapax(tokens_plenos)
    raiz_tokens_plenos_2 = [raiz(t) for t in tokens_plenos_2]
    print('Raízes sem stopwords e sem hápax legômena: ', len(raiz_tokens_plenos_2))
    
    
    
    return False
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/brunorosilva/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
compute_statistics(guarani)
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     /home/brunorosilva/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/brunorosilva/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Caracteres:  626296
# Caracteres sem espaços:  523030
# Palavras:  103688
# Riqueza lexical:  0.10305917753259779
# 0 ('a', 4392)
# 1 ('que', 4283)
# 2 ('o', 3899)
# 3 ('de', 3867)
# 4 ('e', 3587)
# 5 ('um', 1653)
# 6 ('do', 1367)
# 7 ('não', 1276)
# 8 ('uma', 1183)
# 9 ('se', 1090)
# 10 ('da', 1087)
# 11 ('os', 1045)
# 12 ('com', 1011)
# 13 ('sua', 917)
# 14 ('para', 849)
# 15 ('seu', 771)
# 16 ('peri', 728)
# 17 ('em', 698)
# 18 ('as', 697)
# 19 ('por', 655)
# Vocabulário:  5313  palavras.
# Riqueza vocabular:  0.05124025923925623
# Cardinalidade do conjunto de raízes:  4665
# Os hápax legômena ocupam  0.49391727493917276  do conjunto total de tokens.
# ...

# %%
compute_statistics(dom_casm)
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     /home/brunorosilva/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/brunorosilva/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Caracteres:  401523
# Caracteres sem espaços:  336708
# Palavras:  66203
# Riqueza lexical:  0.13662522846396688
# 0 ('que', 2635)
# 1 ('a', 2556)
# 2 ('e', 2172)
# 3 ('de', 1975)
# 4 ('o', 1703)
# 5 ('não', 1426)
# 6 ('um', 782)
# 7 ('é', 698)
# 8 ('os', 666)
# 9 ('do', 640)
# 10 ('da', 629)
# 11 ('mas', 567)
# 12 ('se', 562)
# 13 ('era', 550)
# 14 ('as', 547)
# 15 ('para', 539)
# 16 ('com', 535)
# 17 ('eu', 518)
# 18 ('me', 489)
# 19 ('em', 462)
# Vocabulário:  5916  palavras.
# Riqueza vocabular:  0.08936150929716176
# Cardinalidade do conjunto de raízes:  4806
# Os hápax legômena ocupam  0.5345494748479823  do conjunto total de tokens.
# ...

# %%
compute_statistics(abolic)
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     /home/brunorosilva/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/brunorosilva/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Caracteres:  394330
# Caracteres sem espaços:  320680
# Palavras:  61919
# Riqueza lexical:  0.13926258499006766
# 0 ('a', 2841)
# 1 ('de', 2681)
# 2 ('que', 2193)
# 3 ('o', 2036)
# 4 ('e', 1780)
# 5 ('do', 1205)
# 6 ('da', 1022)
# 7 ('não', 959)
# 8 ('os', 904)
# 9 ('em', 750)
# 10 ('é', 674)
# 11 ('se', 588)
# 12 ('para', 557)
# 13 ('por', 554)
# 14 ('um', 550)
# 15 ('dos', 516)
# 16 ('uma', 466)
# 17 ('escravidão', 444)
# 18 ('no', 439)
# 19 ('como', 424)
# Vocabulário:  5212  palavras.
# Riqueza vocabular:  0.08417448602206108
# Cardinalidade do conjunto de raízes:  4406
# Os hápax legômena ocupam  0.5583903513858286  do conjunto total de tokens.
# ...

# %%
compute_statistics(x)
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     /home/brunorosilva/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/brunorosilva/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Caracteres:  219795
# Caracteres sem espaços:  184502
# Palavras:  35772
# Riqueza lexical:  0.18240523314324053
# 0 ('a', 1494)
# 1 ('o', 1408)
# 2 ('de', 1198)
# 3 ('que', 1118)
# 4 ('e', 922)
# 5 ('do', 685)
# 6 ('da', 624)
# 7 ('os', 496)
# 8 ('para', 348)
# 9 ('não', 337)
# 10 ('dos', 327)
# 11 ('se', 293)
# 12 ('as', 271)
# 13 ('como', 244)
# 14 ('guerreiro', 236)
# 15 ('um', 229)
# 16 ('seu', 217)
# 17 ('em', 213)
# 18 ('mais', 206)
# 19 ('na', 205)
# Vocabulário:  4575  palavras.
# Riqueza vocabular:  0.12789332438778933
# Cardinalidade do conjunto de raízes:  3907
# Os hápax legômena ocupam  0.6049042145593869  do conjunto total de tokens.
# ...
